# %%
from ultralytics import YOLO

# Load a COCO-pretrained YOLOv11n model
model = YOLO("yolo11n.pt")

# Train the model
# We use the absolute path to the data.yaml file we just updated
results = model.train(data="e:/4th Year/AI model/Face-Detection-1/data.yaml", epochs=50, imgsz=640)
